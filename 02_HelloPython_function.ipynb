# %% [markdown]
# # Python tutorial #2

# %% [markdown]
# Function & Class 를 학습합니다.

# %%
def hello():
  print("Hello world")

# %%
hello()
# Out:
# Hello world

# %%
def hello(object):
    print("Hello " + object + "!")

# %%
hello("cT")
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-35-cea5d52696f8> in <module>()
# ----> 1 hello("cT")
#
# TypeError: hello() takes no arguments (1 given)

# %%
def mySum(a, b):
    return a*b

# %%
c = mySum(2, 3)
print(c)
# Out:
# 6

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")
        
    def hello(self):
        print("Hello " + self.name + " !")
        
    def goodbye(self):
        print("Good-bye " + self.name + " !")

# %%
m = Man("David")
# Out:
# Initialized!

# %%
m.hello()
# Out:
# Hello David !

# %%
m.goodbye()
# Out:
# Good-bye David !
