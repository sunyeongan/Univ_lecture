# %% [markdown]
# # Hello NumPy !

# %% [markdown]
# ### OBJECTIVE: Familiarize yourself with Numpy
#
# * This page was created for students to learn Python in the AI (717005) class at Hallym University.
# * 본 페이지는 한림대학교 인공지능개론(717005) 수업에서 학생들의 Python 학습을 위해 만든 페이지입니다.

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])   

print(type(a))            #  “<type ‘numpy.ndarray’>”
print(a.shape)            # 배열의 크기 
print("a.ndim = ", a.ndim)#각 차원의 크기를 튜플로 표시하는 것-> shape
print(a[0], a[1], a[2])   #  “1 2 3”
a[0] = 5                
print(a)                  # "[5, 2, 3]"
# Out:
# <type 'numpy.ndarray'>
# (3,)
# ('a.ndim = ', 1)
# (1, 2, 3)
# [5 2 3]

# %%
b = np.array([[1,2,3],[4,5,6]])   # Create an array with a rank of 2 (rank가 2인 배열 생성)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(b.shape)                     #  "(2, 3)"
# Out:
# (2, 3)

# %%
print(b[0, 0])
# Out:
# 1

# %%
print(b[1, 1])
# Out:
# 5

# %%
print(b[1, 2])
# Out:
# 6

# %% [markdown]
# ### Axis / axes

# %% [markdown]
# * the nth coordinate to index an array in Numpy.
# * multidimensional arrays can have one index per axis.

# %%
import numpy as np

a = np.array([[1, 2], [3, 4]])
print a
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
# * If not specified, the overall mean will be obtained
# (지정하지 않으면 전체 평균을 구하게 됨)

# %%
print np.mean(a) # 2.5 배열 요소의 평균을 반환
# Out:
# 2.5

# %% [markdown]
# Axis 0  (↓)

# %%
print np.mean(a, axis=0) # [ 2.  3.] axis(다차원 배열의 축)
# Out:
# [2. 3.]

# %% [markdown]
# Axis 1  (→)

# %%
print np.mean(a, axis=1) # [ 1.5  3.5]
# Out:
# [1.5 3.5]

# %% [markdown]
# ### Broadcast
# * Calculate arrays with different shapes
# 형상이 다른 배열을 계산하기 위해서 지원하는 기능

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])
print(A)
print('--------')
print(B)
# Out:
# [[1 2]
#  [3 4]]
# --------
# [10 20]

# %% [markdown]
# Please observe how it is multiplied. (어떻게 곱해지는지 잘 관찰바랍니다.)

# %%
print(A*B)
# Out:
# [[10 40]
#  [30 80]]

# %% [markdown]
# ### Stack

# %%
a = np.array([1,2,3,4])
b = np.array([5,6,7,8])

# %% [markdown]
# * stack vertically (세로로 쌓기)

# %%
c = np.vstack((a,b))
print(c)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(c.shape)
# Out:
# (2, 4)

# %% [markdown]
# * stack horizontally (가로로 쌓기)

# %%
d = np.hstack((a,b))
print(d)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
print(d.shape)
# Out:
# (8,)
