# %%
from __future__ import print_function

from keras.models import Sequential
from keras.layers import Dense, LSTM,Activation,Dropout

from keras.optimizers import RMSprop

import numpy as np
import random
import sys

# %%
text = open('/Users/anseon-yeong/수업/2021-2/텍스트정보처리/week13/13주차_txt/shakespeare_final.txt').read().lower()
characters = sorted(list(set(text))) 

print('corpus length : ',len(text))
print('total chars : ',len(characters))
# Out:
# corpus length :  196788
# total chars :  63

# %%
#모델 학습전 전처리
#1. 전처리 : 주어진 전체 스토리 텍스트 파일에서 X와 Y 데이터를 준비하고 벡터화된 형태의 인덱스로 변환
#2. 딥러닝 모델 학습 및 검증 : 딥러닝 모델을 학습하고 검증
#3. 텍스트 생성 : 학습된 모델로 텍스트를 생성

# %%
char2indices = dict((c, i) for i, c in enumerate(characters))
indices2char = dict((i, c) for i, c in enumerate(characters))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 65583

# %%
X[0], X[0].shape
# Out:
# (array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False,  True, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  (40, 63))

# %%
#모델구축 
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(characters))))

model.add(Dense(len(characters)))

model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))

print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               98304
# _________________________________________________________________
# dense (Dense)                (None, 63)                8127
# _________________________________________________________________
# activation (Activation)      (None, 63)                0
# =================================================================
# Total params: 106,431
# Trainable params: 106,431
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#예측을 인덱스로 변환하는 함수

def pred_indices(preds, metric=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / metric
    exp_preds = np.exp(preds)
    preds = exp_preds/np.sum(exp_preds)
    probs = np.random.multinomial(1, preds, 1)
    return np.argmax(probs)

# %%
#모델 학습 및 평가
for iteration in range(1, 30):
    print('-' * 40)
    print('Iteration', iteration)
    model.fit(X, y,batch_size=128,epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.7,1.2]:

        print('\n----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(characters)))
            for t, char in enumerate(sentence):
                x[0, t, char2indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = pred_indices(preds, diversity)
            pred_char = indices2char[next_index]

            generated += pred_char
            sentence = sentence[1:] + pred_char

            sys.stdout.write(pred_char)
            sys.stdout.flush()
        print("\nOne combination completed \n")
# Out:
# ----------------------------------------
# Iteration 1
# 513/513 [==============================] - 14s 27ms/step - loss: 1.6720
#
# ----- diversity: 0.2
# ----- Generating with seed: "t, burn out the sense
# and virtue of mine"
# t, burn out the sense
# and virtue of mine and me the manter of the went the was the manner to hear the wat to seen the manner of the was the king and to the was the was what so the was the was the manners and to hear have to the was the wail the wat the wand and to the was the manner and may to he with the was the wail the was the wail the manner of the wail the wail the was to the wand to the may to the wand and so the wat to the was th
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "t, burn out the sense
# and virtue of mine"
# t, burn out the sense
# and virtue of mine be he the wat havoung till the mint of ingeant she sucle think in it our the would and for’t to hear, with the wad’d give gull the bean, stall sony, your and let the laiders our some my heaven, what steet count there of reenver me to sole? how if hourtul the way, my lood whire protenter sould most with have mustly. both have grave he wall of hert o, the wing for the lay in arrance should fram the
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "t, burn out the sense
# and virtue of mine"
# t, burn out the sense
# and virtue of minesy noast
# canstet-op, if fring inuws. thon to ubeary.
#
# king. deat._]
#
# hamlet. hathor. the athour. let so; that i will with obely
# hear; seaw?
#
# , in youttrent
# doself. now lovey?
#
# frone. in cannard liws not becurs bear voily.
#
# hamlet. ’cast deld. whilet, aporay, now your ear
# brove .ow would nos on
# ave ophelt not e5on.
#
#  laertes. you ruscreedien. them on the rodbly right what nons them, old rever frten
# One combination completed
#
# ----------------------------------------
# Iteration 2
# 513/513 [==============================] - 14s 27ms/step - loss: 1.5791
#
# ----- diversity: 0.2
# ----- Generating with seed: "s of blood,
# disasters in the sun; and th"
# s of blood,
# disasters in the sun; and the countright to some in the countries of the conder to the countries of the countries of the project
# gutenberg-tm electronic works in the conse to the countries of the speak of the countries of the conder of the contriat the countries of the countries of the countries of the contriat to so his any conders of the countries of the contries of the contriat the countries of the conceing and the countr
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "s of blood,
# disasters in the sun; and th"
# s of blood,
# disasters in the sun; and this where not my unclants of he so.
#
# enter mose a copyrigutenberg—our own with revillast, of promes; and but rean tone to itself
# liveral my be way bo you, and i know this canspliness to ching is trie connounty
# kings, bethers curnity and works boom hear of the speak his
# sout the more in kind sift of all the ound, when i soul; for be at whe contling and not nover?
#
# homatio. a room i ray say, the part
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "s of blood,
# disasters in the sun; and th"
# s of blood,
# disasters in the sun; and th’s? my
# reev tot ad very
# most vomy hor? i kell hear’ednt.
#
# gint ’time ot you dmi?, encenilaw to sove ween,
# will pooring his ownt to cop
# feice, i speak, gentle, drlep nobleve hear bus’d, runkings of
# ayiswayurtrant
# .siffers._]
#
# hamlet. the cadce nothing
# wrygret
# she arroper_at
# shaust vad herees iy thainchin.
#
# murood is exce
# add
# discrost of stenlen ebcelts, windarn?
#
# ophelia. ear year say, you seall wi
# One combination completed
#
# ----------------------------------------
# Iteration 3
# 513/513 [==============================] - 14s 27ms/step - loss: 1.5044
#
# ----- diversity: 0.2
# ----- Generating with seed: "laertes. i pray you, give me leave.
#
# dan"
# laertes. i pray you, give me leave.
#
# dance give a reass of the more the the the more the more the manners the carrarion of the manners the conse of the fertim a man your son the more the pertrant the world here the states the states the more the most the more the more the let the manners the gentleman, and the world the castle the pertrime the more the castle.
#
# hamlet. i have your serve of the castle, and the more the lends the castle.
#
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "laertes. i pray you, give me leave.
#
# dan"
# laertes. i pray you, give me leave.
#
# danes. you comm.
#
# hamlet. what is think i heart thou know a gailar of a shoutes the more avooure the words fortune, and blay, the beatome of eyvence the in that of a could the letter a charies, an a partion inrexts where a ningen the be not the all’d is sible our our serven a the the fortune th’eath the cant to go that you, the no, thou forture and command that i have benesy, as i have thought the me
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "laertes. i pray you, give me leave.
#
# dan"
# laertes. i pray you, give me leave.
#
# danks_a ochelis, in my masi bice a stise, anurmin, som. fowest the
# user, the mouth, wherefounks for into plues, unbesiot. bleanies.
#
#  oshd so spire green, he lovermancy your ! comequne, gaven.
#
# ophelia. how it such sweeps, my lord, my
# hambay lesogh,
# know if impartion fortunacd; on umuner.
#
# rosencrantz her camtus._]  en;er.
#
# hamlet. i guddenses. you, sir.
#
# hamlet. pophee, lofe, gave, beense than roth
# One combination completed
#
# ----------------------------------------
# Iteration 4
# 513/513 [==============================] - 14s 27ms/step - loss: 1.4494
#
# ----- diversity: 0.2
# ----- Generating with seed: "ng any fees or charges. if you are
# redis"
# ng any fees or charges. if you are
# redistain to the free he of the hath the bear to the mading the matter and the more the matter that i thanks of the contann and the that the matter and the more the more the free and his the made the mading the beath the state of the free he hath his life to the castle.
#
# hamlet. i will have shall in the cantle that the matter of a shall that the mading and to the play the mading in the castle.
#
# hamlet.
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ng any fees or charges. if you are
# redis"
# ng any fees or charges. if you are
# redistrinus and paragen my patter that which of hamlet of paces, expince, to the young will be will we that i have, and passion comes of offenches hath let shall not. o his bice be thee shall im a vire his pattrass, that i have strentle that him elsement to your maxtly that of dasilet shall do, shall will bod with marrrate they state be heaven of most a not on the have see looks of have shall see with
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ng any fees or charges. if you are
# redis"
# ng any fees or charges. if you are
# redistat
# in ac ow bpeal, shood his like for
# to
# gropt. thee killy me.
#
# worcuit lows.
# ’ofrtormant, is no have piration, wes’s i oxthelen hend his jottre; from putchrance in the fimements?
#
# frant. one.
#
# hamlet. tear unhth hen emwie’’s that be shave
# risting the habie trhees thy play a birerame, why shall be cusp?
#
# king. they gap, all
# inax to by, shaken any strop.
#
# remeneavamay yait
# come about woold frian,
# One combination completed
#
# ----------------------------------------
# Iteration 5
# 513/513 [==============================] - 14s 27ms/step - loss: 1.4102
#
# ----- diversity: 0.2
# ----- Generating with seed: "n thrice blasted, thrice
# infected, thy n"
# n thrice blasted, thrice
# infected, thy not the cast the word the word to have the beath, that i will the part and project
# gutenberg and project
# gutenberg-tm electronic work, the that it well the ways.
#
# hamlet. what is my lord.
#
# hamlet. not it sare the strow the suncle that the shall the play the ways.
#
# hamlet. the say you may my lord.
#
# hamlet. what is is my lord.
#
# hamlet. not it see the word of the word of the suncland of the word of co
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "n thrice blasted, thrice
# infected, thy n"
# n thrice blasted, thrice
# infected, thy not.
#
# hamlet. what be you, be discove of the will here and the matter.
#
# hamlet. what bark the word
# that, when they well, my lord, of herself be not it to retay as his parture math, my lord?
#
# hamlet. not he hother hather, the castee.
#
# hamlet. a more that, ear.
#
# horatio. i do my sord, my lord?
#
# hamlet. hamlet. have not and our his abowed cape than that by put mad, hath for night. what would be though
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "n thrice blasted, thrice
# infected, thy n"
# n thrice blasted, thrice
# infected, thy not, are?
#
# horatio. gax it, welds, how now loed and hath eason. some orritats homesoth’d, doth. there with a most hagh most the bronget.
#
# polonius. whlle cage; but he, noll outly thingd huminut take give phase flathe.
#
# hamlet. ay, what is abo?
#
#  [_forthlesazcally she put of it, marrcheon, on englich. wos not, since; eabs other, at starply; theirricainfully have
# givts shand well trane! figly fay eng
# One combination completed
#
# ----------------------------------------
# Iteration 6
# 513/513 [==============================] - 14s 28ms/step - loss: 1.3736
#
# ----- diversity: 0.2
# ----- Generating with seed: "nted pace; but there
# is, sir, an ayry of"
# nted pace; but there
# is, sir, an ayry of the canning at as the states the strange, and the most agree of the stand of the be the work of the thing the states the states the states the strange, and in the cannit in the castle it ways the states the strange, and and the players.
#
# hamlet. the deady in the most intell the mannes of the castle.
#
# hamlet. the deady in the stronger that the most agree and the states the strange, that i have the
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "nted pace; but there
# is, sir, an ayry of"
# nted pace; but there
# is, sir, an ayry of and pose, but, sith marry is the states, stange of nother against the adsiff dost the work of the bose, and in llowing notess and a madnes she offence of father the ourselly, comment it project gutenbergvtf for his possess, come, stricle as
# lemand your not your last gratuly be op. brother are so, and esport the most sunds.
#
# hamlet. the nemes tellons dishippon af the project gutenberg-tm a recoune
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "nted pace; but there
# is, sir, an ayry of"
# nted pace; but there
# is, sir, an ayry of e’ent agier of the but he’s ofr withot, and ourd gove be ophelion and biested litter?
#
# hamlet. for a
# midvem we camshing echom fring in this?j_t rothing lord. o inttrese,—hi’ my curnasion lend other take by notant rither
# fong for tamestoutk!
#
#  tshelits mad very it,  he le, that lettersheriare
# i, the nature for
# , ’twith
# whe corn
# thou trankgres, for shot, and grownuchy; thishes to ak
# ’tish, lan and
#
# One combination completed
#
# ----------------------------------------
# Iteration 7
# 513/513 [==============================] - 14s 28ms/step - loss: 1.3456
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# rosencrantz. as the indifferent childre"
#
# rosencrantz. as the indifferent childres of the day to the carness of all the consess of the strunge of the dain the carnes of a compoles of all to some some to the recombing of any of our of the carrigute of as the consess of distractes.
#
# hamlet. what work the carness of the consess of a chrie of the some of the songer and the could the speak of the stronger of the dain to stange.
#
# hamlet. i so confest to show you, and whis work to sh
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "
# rosencrantz. as the indifferent childre"
#
# rosencrantz. as the indifferent childres in not your heads if fages stangencess, and be not works out the uncopy speak of a madkess not be than and tor of a blongy to
# sweak him and your eyorant done is way and eyes of gantes to the part and consecond a
# mort day to speak are of which admitience at but offess of brish to laid about to sheilly to terms of lord.
#
# hamlet. not be morn. i have not be soul, her of the took not whose of the pla
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# rosencrantz. as the indifferent childre"
#
# rosencrantz. as the indifferent childres. but you
# says. rewers hamlet.
#
# polonius. inot drokn. my lord, im, ow’t your revenveral oted breed damakerous,
# now that mestage, lentsemarn. staif mme’llnat-len; sie, hamlet od? the dain; noomhssemote; respreed,
# and by hims offes o fin within
# mistllum. my lord, you know by not.
#
# hamlet. nay, then is be ’tity a equertise. methe leads, agring
# , in poles as wiul do? refe! are not. on you, whing, let
# One combination completed
#
# ----------------------------------------
# Iteration 8
# 513/513 [==============================] - 14s 28ms/step - loss: 1.3194
#
# ----- diversity: 0.2
# ----- Generating with seed: " what hour now?
#
# horatio. i think it lac"
#  what hour now?
#
# horatio. i think it lack the same the play.
#
# polonius. i do the rections mark the pertrand the speaks of the sun._]
#
# hamlet. i so confest and the candirdons of the sist the states of the world the states of his burnants for the dear the play.
#
# hamlet. i do the speak of the cunsert to the reclide, and the beauty are the world the project gutenberg-tm electronic works and the dear a should have the cands of the terms of t
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: " what hour now?
#
# horatio. i think it lac"
#  what hour now?
#
# horatio. i think it lack nor seef in es.ing the unwoctuen. what father’s but his sould king of a remont the beauty here about the recling will return his hath
# break of a father, e would me too o, pradies, for now as i do be be cornick at a stonge of liven the that to play
# to your laugher be the comtomest and whil’s followill if i dearthing which heaven, what and sand at by wite my to affline him marrate the bought hath
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " what hour now?
#
# horatio. i think it lac"
#  what hour now?
#
# horatio. i think it lack?
#
# ovelies. be.
#
# rant to.. si; amtil, from th’onchirson and bles._]
#
# uepress. i if, i’ll thus
# eost ind hig it see; what it underow mire, and doen by ceec. i mo, that shaw to cheed it.
#
# horatio. my father.
#
# horatio. suray, most hethir’s liventywso’s his cupmels his unco.’s that you on her eye.
#
# upselvs.o. a most certabn
# deved: that ouh helve; oilk
# friend your foilt.
#
# clorand suct of cloon, ’tis sa
# One combination completed
#
# ----------------------------------------
# Iteration 9
# 513/513 [==============================] - 15s 28ms/step - loss: 1.2993
#
# ----- diversity: 0.2
# ----- Generating with seed: "and guildenstern._]
#
# come, gertrude, we’"
# and guildenstern._]
#
# come, gertrude, we’ll pooon him which him to the unwast and the king and to me the players are agreement to the matter to the country that i have hather of the country and the king the king to the king the king the king the matter and where is the manness and more to the country and the king the king the body of the unwally
# the king to the player hands are of a stood the tonterate of the country to the dead be again
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "and guildenstern._]
#
# come, gertrude, we’"
# and guildenstern._]
#
# come, gertrude, we’ll foundation days of the uncation for him comes with the offerour and the manners states me make and deady and first contame not
# commind and your distracter.
#
# king. o’ht we know whereon the arrull—spoul palact dawnerelius, and all done the play’ous of the fing the purt of paragraps of frominorn the toppurmantial, or the hath be work to that de’s with a wortom hatheat to the think reven the arm ow
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "and guildenstern._]
#
# come, gertrude, we’"
# and guildenstern._]
#
# come, gertrude, we’ll; come, ho, do?
#
# king. ayt telk and from me opheldo, to works wing’d, as agree that, as i our knows trive us, that i have nast for’t
# fortayvere and
# did impaba?
# hamlet. my lord! i mmell._]
#
# fortunats oner madne seln pothor’d to
#  his
# cluritled
# do, barrardo: what me.
#
# horatio. in eyes scarren a rett in then utenterslaincl, mpoor’d,om; thereys kidgs to fork ap like of pauritation tremagantway it sou
# One combination completed
#
# ----------------------------------------
# Iteration 10
# 513/513 [==============================] - 15s 28ms/step - loss: 1.2817
#
# ----- diversity: 0.2
# ----- Generating with seed: "that spirit upon whose weal depend and r"
# that spirit upon whose weal depend and return and the cansle be the cannot her of the cannot the play.
#
# hamlet. i see the castle.
#
#  enter king. i see the castle.
#
#  enter horatio.
#
#  enter king. i said the castle.
#
#  enter horatio.
#
# horatio. if you say the cannot to speak of the cannot the play.
#
# king. a man, hamlet’s most force of the cannot the castle.
#
#  enter hamlet.
#
# horatio. it is not the castle.
#
#  enter horatio.
#
#  [_exit._]
#
# hamlet.
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "that spirit upon whose weal depend and r"
# that spirit upon whose weal depend and rose hear.
#
#  flanin. to pleas’d in this gine and discount and find a passive must bean, the hast please houre, and in thy shall read
# the some and
# fireft, my lord.
#
# hamlet. i love rank my liff gode. o’ld madness. is dost love thou hast this : will be not, and i cann tinge, do be drows.
#
# hamlet. you shall not look your hears of and quick your have project to
# and for unine access to be usinious percus
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "that spirit upon whose weal depend and r"
# that spirit upon whose weal depend and recovertues. if this men and very
# sude.
# the confound as your. his lifts should, for it!
#
#  thereplabmont my lord?
#
# hamlet. rises._] why suf o this  o’er remem you roin paetse of you.: sis
# chardiog’d.
#
# rosencrantz. marray.
#
# laertes. give well, good with empurtues hath and fattently liselates beignect or
# cass of trice of this breednen the fiest cunsequhist with a plad for beratila
# iess
# cunce
# tme, two.
# One combination completed
#
# ----------------------------------------
# Iteration 11
# 513/513 [==============================] - 15s 30ms/step - loss: 1.2666
#
# ----- diversity: 0.2
# ----- Generating with seed: "l keep her word.
#
# king. have you heard t"
# l keep her word.
#
# king. have you heard them to my lord, in the cannees on the canster in the castles or distribute or the charge your state of the carriage of the sings, forget the carriates, which is the castles the carriage of the creass, and in the cast to the first and feed to the first and the body in the castles him, and the first and the carriage of the cansterate, the shouldends to the terms of the certain to the first and shall
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "l keep her word.
#
# king. have you heard t"
# l keep her word.
#
# king. have you heard the corderlitate and from his parwacted, whereincting be[ker from me
# iecious
# well me holds for the chald not i toney
# are rest.
#
# hamlet. i’ll well to they siry thee in nor all
# scene we cannot of
# the change
# this foold indeed, in the freating himself not better in their adment i am it the stage.
#
# ghost. let me horatio, have the first for the
# fidseres herens there and admsition to be players drark free
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "l keep her word.
#
# king. have you heard t"
# l keep her word.
#
# king. have you heard tonguert shall nigh’llows, pringly gave you with the very may camsk, the
# inflession nop, the
# proknows.
# dearry
# gapbandmer forlplicad have says withtence; make then. or lord; forty good never is us, it
#
# words you drave_, fort we canner unint to
# a mation
# fearsical patilly is tende,
#
#  be your dudy’d
# gross, man. now evilla; that was obeut oor no. o moject nor sot -usite and
# resple assicive carn’s neus,
# One combination completed
#
# ----------------------------------------
# Iteration 12
# 513/513 [==============================] - 15s 29ms/step - loss: 1.2556
#
# ----- diversity: 0.2
# ----- Generating with seed: "e two months ago, and not forgotten yet?"
# e two months ago, and not forgotten yet?
#
# horatio. i see the play.
#
# hamlet. what is me he we should be the prorts and the proble as a son and the bloods the be with the the be of the bloods in the bore the prorts of the earth an a man’d the commanding to the prorise the pront untraverance and the be not should be the prorts of the sistericaloniess.
#
# hamlet. i see the glous my lord, i have so have the play. i see the ways my commandition
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "e two months ago, and not forgotten yet?"
# e two months ago, and not forgotten yet?
#
# hamlet and hasth of his right, grave, my come in the purmows the more
# in his worter
# bood most morth you, with a man, horrita are your waynous you as your life that is a mather all we provord, frymen the castle a ways to she speak to as free
# seers of commis’d it to me not the proat
# apoles a most grave of youn the unk’d, my sun a grows in the sleple a kindthen for unford, not for a shows, compussi
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "e two months ago, and not forgotten yet?"
# e two months ago, and not forgotten yet?
#
# horatio. is word let me of accown, bound
# him is not it whrek his courtest save eyeanis of a
# casame thy fioury,
# haste well, mery obshe refund ophelia?
#
# hamlet. nor my words most unknots of intow your phiss how are been their mainswudgringince on they but
# hefal.
#
# eyoun.
#
# hamlet. "
# himent mud!
#
# polonius. myszencrow. he sly, my lord. we caid of by not’s mechistaca us gree fenor’s modesgown must is?
#
# One combination completed
#
# ----------------------------------------
# Iteration 13
# 513/513 [==============================] - 16s 30ms/step - loss: 1.2440
#
# ----- diversity: 0.2
# ----- Generating with seed: "utenberg-tm name associated with the wor"
# utenberg-tm name associated with the works the speak of the shouldensters, and with the sings, and with the hast the feel be the beaught to the state.
#
# king. i have set not so his particull he done, and shall not be seems, and with the at the hath our such with the hands of the enemane, and with the the shall in the haste of the ears of the beaught to the singer and the shawed of carriage of the enemane.
#
# hamlet. what is there heavens a
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "utenberg-tm name associated with the wor"
# utenberg-tm name associated with the works shall we hath in the sensee’s break of your off, and shall remember’d, with a matter.
#
# laertes. give ession he holds, now the full within there.
#
# horatio. ay, let me we hathers no more to know the partically takes it the beaught itself; but,
#
#  [_readly._]
#
# rosencrantz. ther to royment them it say, and
# we him, to your other project
# gutenberg-tm
# electrongus as it work on wisding wisder done.
#
# que
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "utenberg-tm name associated with the wor"
# utenberg-tm name associated with the works with the [_bequeen’d unders, oselic to possafes.
#
# horatio. these players,.
#
# first clow fuse, one expense
# so’d,
# fiebeeto’t?
#
# hamlet. then atcly, brow, do in know himself shallst the ber.
#
# ender. hol
# donina, you
# swrikn marry.
#
# hamlet. repring ot him presebants, fest
# raviourlibuld to drquese’d marked what lend wifen
# of his bientles, where vious his triest
# doth,
# gemtlemas. the shose here letters an
# One combination completed
#
# ----------------------------------------
# Iteration 14
# 513/513 [==============================] - 15s 30ms/step - loss: 1.2330
#
# ----- diversity: 0.2
# ----- Generating with seed: " resembles that it was.
# what it should b"
#  resembles that it was.
# what it should be the prooting that the prootion from hearts of the proound. the most some may not so have that i will be agreant of the project
# gutenberg-tm works in the canspead matter shall the project gueenbereement and the proot of the prootiniess.
#
# hamlet. i have the passion is not the project
# gutenberg-tm works in the proound the part they beaution are age of the proot of the proot of the proot of the play
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: " resembles that it was.
# what it should b"
#  resembles that it was.
# what it should best thou shall the pits undering to us too the protestion shall stay abroom, and so sets, it she protest the
# passion see’s let me a sleeps to thou know this was a rook are as they retermestaguitus, the
# could it and angent is the hast of the gently of surenostate fill for of user. still we sone to your eyes like the world, which thou may cominert.
#
# hamlet. i have lier. well, horatio. no marn that i
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " resembles that it was.
# what it should b"
#  resembles that it was.
# what it should be the , gert not to’enshoup aloot
# whom down.
#
# hamlet. hear hather seen sog yqu too tasbe
# forse.guest poloupius. upon.
#
#  [_exeunt the cent you we saratnguth, they
# belinught most
# mark
# habl. howratio.
# i pritsane, for eyeswent quessed papg. to counies asp-lise pittle that soul by for.
#
# hamlet. ’exelorma’dy in  deans obes, my awswme about him—e
# fanty, give smelvo
# codpaubiturience of dreadnus.
# queen, th
# One combination completed
#
# ----------------------------------------
# Iteration 15
# 513/513 [==============================] - 15s 29ms/step - loss: 1.2186
#
# ----- diversity: 0.2
# ----- Generating with seed: "three
# liberal conceited carriages: that’"
# three
# liberal conceited carriages: that’s father gave you and the king the platfurm and contrand what is the deady of the beauties the matter that i will with
# your laertes in the canst to the blaw to speak to speak to comes and the players the kings of the cannon you and the king the canster in the cansted be when the canster in the cansted to the cannon you and state, and the players the kings of the gentrable that in the canster in th
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "three
# liberal conceited carriages: that’"
# three
# liberal conceited carriages: that’s where hath shall speak of never these said fall to my god curnial particulate like oppories. the matterer thy father.
#
# king. be what is not me and the king is the king the fee with him my hearted more the then may charist to heart change atienct propose trank usinier guildenstern.
#
#  [_flord no some are been them to chardry for the castle, it awalentabe, and the kings here and let and the king.
#
#
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "three
# liberal conceited carriages: that’"
# three
# liberal conceited carriages: that’s fromlis.
#
# hamlet. ?
#
# guildenstlere.
#
# eart what do my lord.
#
# first clownatio. nerinw not chard players.
#
# polonius. i see ten. the ckry and soul that hath rejudg-ggod loed for uses all project gutenberg-tm enolon, that thus and court,
# to the gaded as
# y, orex, reveng? why
# atis hend chamment and peld quice, more drother.
#
# meennar. for dear goes. smage have
# never knot pactange.
#
# capanir. rope
# accast
# One combination completed
#
# ----------------------------------------
# Iteration 16
# 513/513 [==============================] - 15s 29ms/step - loss: 1.2121
#
# ----- diversity: 0.2
# ----- Generating with seed: "mation about donations to the project gu"
# mation about donations to the project gutenberg-tm works in the cander for the project
# gutenberg-tm swors the project
# gutenberg-tm works in the consent the part call the piting to the project
# gutenberg-tm works the project
# gutenberg-tm works on the project
# gutenberg-tm works in the cander with the project
# gutenberg-tm works in the project gutenberg-tm seens the sense, and the beaution and the sonce not so the project
# gutenberg and my lo
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "mation about donations to the project gu"
# mation about donations to the project gutenberg-tm i am molt.
# shall for this particular phise, against the strone like to
# nature, hath and so prison! give is dears. come, and of the contantion, here should stais uncons, and in
# the done, what can you we as incland himserfully part call the norsing not
# and
# forth, hath in as ear him.
#
#  [_exit._]
#
# hamlet. ’twere that hath you,
# so you trane, the let as know, and the dead states of
# a project
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "mation about donations to the project gu"
# mation about donations to the project gutenberg-tm lord
# demand grave
# spolce. perhosunce for.
#
# hamlet. good noble a moded
# perdown you o parsias, jet? the ear._]
#
# ghost. [._]
#
# hamlet. shore.
#
# polonius. if it wall kee you lays me to you.
#
# ghatts. we, indied. he, my lord.
#
# marrard. ay, my lord, pronor.—
#
# laertes. blachss knoise, traisgration evene’s no same of this, like about your grief plet
# you means more hers, and
# recking
# th’onnarrey.
#  [
# One combination completed
#
# ----------------------------------------
# Iteration 17
# 513/513 [==============================] - 15s 29ms/step - loss: 1.2069
#
# ----- diversity: 0.2
# ----- Generating with seed: " desperate grown by
# desperate appliance "
#  desperate grown by
# desperate appliance the hambertain the project gutenberg-tm work as the cast and the castle me of the terms of the castle demiger and the thing the matter shall with the cast and the pressination that the morn the project gutenberg-tm work is may down a shall your of the project gutenberg-tm work of a man and the some of the crease of the distribute of the sister of the free done, that is the strow the castle done, t
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: " desperate grown by
# desperate appliance "
#  desperate grown by
# desperate appliance the free a should balks, and a man; for heaven, and underits, and will he hath some, and the said and to the nister, be with ling the beauld the for him, and where he hath shall well._]
#
# hamlet. they believe me, you may come to his parts of your
# prisess as you have the brother’s hamlet the grave.
#
# hamlet. they word hamlet, see should madness where dear that else more shall deed young from the done
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " desperate grown by
# desperate appliance "
#  desperate grown by
# desperate appliance to thou know
#   enold each juckge no wristeeer as prison me, which deving he a callurs. shalonst me. and this vouce in his and in?
#
# hamlet. are you is by with miw’ o_h, and brought to be bown’d?
#
# first callect all are to
# sent feat i lare? i sa1. we awail’d even they willical
# yous; and you drask dec. i will be more. o me sweet
# and in your lableight such a masterast as he sense’ thats
# forrtible unwo
# One combination completed
#
# ----------------------------------------
# Iteration 18
# 513/513 [==============================] - 15s 30ms/step - loss: 1.1903
#
# ----- diversity: 0.2
# ----- Generating with seed: " was mad; he shall recover his wits ther"
#  was mad; he shall recover his wits there and the bloody and contracter.
#
# hamlet. what is me and be shall him by the project gutenberg actions say the blain to be think the castly.
#
#  [_exeunt rosencrantz and._]
#
#  [_exeunt rosencrantz and guildenstern._]
#
# hamlet. what is is not the cast he drown and charge and chiliand stand of the uncation man the strong and the beaut of the hambertains of with a morth of this bloody manners and charge
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: " was mad; he shall recover his wits ther"
#  was mad; he shall recover his wits there come elechinet
# dear hather how in the some aughth
# in fast the englanden with down and wheising in this both in me not are our with
# do not make you say cansterain and forth you are percomes holatio, and to
# your with sonts with all the every work in the uncop’d the patter
# that him shall be thee, the yould obey heavens that all the
# at a chaliance with not mad? sith or hepoun, her mother, for make u
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " was mad; he shall recover his wits ther"
#  was mad; he shall recover his wits there works.
#
# horatio. tengerath, em’t.
#
# hamlet. i think it. becoment soldical
# not ever but he wap toreime, you wahuse it make you fellows.
#
# hamlet. i do we that, my must, my lord.
#
# ruy. what, lady ungrot him wrev
# le’s rerembfullicentions beom’d, whileasd, horript; whereings from this
# ype
# eaenty?
#
# ophelia. room rehnaver lows, squee
# done-thmip valend me, as too,.
#
# hamlet. no me?
#
# hamlet. beov’d,, wexpf
# One combination completed
#
# ----------------------------------------
# Iteration 19
# 513/513 [==============================] - 15s 29ms/step - loss: 1.1851
#
# ----- diversity: 0.2
# ----- Generating with seed: "all. i would not, in plain terms,
# from t"
# all. i would not, in plain terms,
# from thee that i was the platf my lord, sill, though of the conceint and the phossour of the world is a charion and conceiv’d and strongers are as he is the cast to the play.
#
# hamlet. the pood marry and the matter to hear.
#
#  [_exeunt rosencrantz ancz.
#
# king. o my lord.
#
# hamlet. there and there and there and there and wherein the peremand as the cast to this agree and the some be with a man the project
# g
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "all. i would not, in plain terms,
# from t"
# all. i would not, in plain terms,
# from this, i have whose now mad’s of chiliald to th’extruther and dead the
# morn that this plack to stange of your life, and for no matterall
# words for this plach as with the
# cast hit of a ching of your aucht, but in hamlet
# pray he lord with that was guly.
#
# first clown. the thought me shall be
# more this, though but i me not thee shall
# has he looks the caster’d this my sout.
#
# king. this acroand, dear lord
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "all. i would not, in plain terms,
# from t"
# all. i would not, in plain terms,
# from thee in;ayfy,; with speak be.
# horatio, what hamber tone
# chauld do; he lat thee. most sir, so put thee?
#
# first playacn. o my lord.
#
# first clown. ; haponows call is be fast say’ar.
# readitlus.
#
# first clown. prov’d in themome th upkns, charge thus
# kingds present you be perege up eyhs.
# alas sleepion we may demake desire you of mapss, re?
#
# king alo?! sit!
#
# horatio. posd in you one exucells you faar, to
# b
# One combination completed
#
# ----------------------------------------
# Iteration 20
# 513/513 [==============================] - 15s 29ms/step - loss: 1.1807
#
# ----- diversity: 0.2
# ----- Generating with seed: "e
# made a good end. [_sings._] for bonny "
# e
# made a good end. [_sings._] for bonny the players to his matter shall be this players for the players. this all but i see the play the players to the body is marched of this access to the players state and fiest to the players do
#
# hamlet. the players to his beauts, where is not the castlance of this all the players to the players do
# not the body is not the castle state of the strone that i will not be a reasound of the players for the
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "e
# made a good end. [_sings._] for bonny "
# e
# made a good end. [_sings._] for bonny the players to be done, that mad, i
# some may not fied with a
# firhers, you was mades, than a sight confess to make a fin is fine of call the ne to yers for the cassla
# dong the garse of playeract of it as heaven be thund betten him to chiliration most marchirs’d you the hast to be thou saffertant on hers all i’ll strabble even spreak of project gutenberg-tm swould speak! or call this near dicare to
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "e
# made a good end. [_sings._] for bonny "
# e
# made a good end. [_sings._] for bonny makes marry and wind, aly made of truse days5l oppyrtanolition forehing. wher’on of slack; but joscjets, as it doed and confence. they be they way gated that we
# any her
# vies, law’s than humber mapplestances low his project guter.
#
# will nockess what is mar, why, my lord.
#
# king. ophelia
# sall of my forch, to that becabor, as it be! led terres to do
# sid-ey.
#
#  [_exeunt, done
# waw, lock being demand ry,
# One combination completed
#
# ----------------------------------------
# Iteration 21
# 513/513 [==============================] - 15s 29ms/step - loss: 1.1718
#
# ----- diversity: 0.2
# ----- Generating with seed: "ment will not be
# liable to you for actua"
# ment will not be
# liable to you for actuagence on the project gutenberswor’d.
#
# hamlet. the king shall not be some man that in a charge as the blainst the fingers of the handshing the first will on the struppowes that it work must matter for the some on the handshound that shows the father poilt and the states with the propertate of this all foundate or orrow of the stand of the handshound that than a ware the still the states right of th
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ment will not be
# liable to you for actua"
# ment will not be
# liable to you for actuaies and some may con
# it, or
# clant that i am heads that it meet as in the singst?
#
# horatio. i am giones, sit, we
# prop that the havenow of grief, you say the most regasd the hands, though and but this bereasty charge as the
# as it noterpsing bear that in the fitus and eching the shad not, so whose a am took the conpulit’d the man thy respied to speak father.
#
# laerte. and the some do by chappolle be b
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ment will not be
# liable to you for actua"
# ment will not be
# liable to you for actuagenfen and cobectes, you know by her doin a lict of his works dire?
#
# hamlet. unt comms hathear. the habiest, it facesiry:
# ingevend whet the speen confistery othen? make you do wrate be these at themaiths he stull done you undecdioning the nement beas welc come.
#
#  ense lead noake lose ungreed with poponica, to
# times her, when their danes, and most
# corfuinie, pownat, fortinfe ’aimsitome or flash a r
# One combination completed
#
# ----------------------------------------
# Iteration 22
# 513/513 [==============================] - 15s 29ms/step - loss: 1.1652
#
# ----- diversity: 0.2
# ----- Generating with seed: "ied o’er with the pale cast of thought, "
# ied o’er with the pale cast of thought, to the fire to the terms of the consequentent to the terms of the consequentent to the general lither what is the castle
# shave of cass and the fingled project gutenberg orgus and the most most contrable of the consequente of your lord hime a grown the castle.
#
#  enter horatio._]
#
# hamlet. there’s a guilty marver there and with the consequente of your own hearty but the castle
# some at a project guten
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ied o’er with the pale cast of thought, "
# ied o’er with the pale cast of thought, and whose off in this good
# dame’s the more more with lestrould the world up wor. harhs guther on cremant to such a rasial riseen with such downing friend to priencly to
# sweep the manvartis.
#
# king. hamlet, good my lord.
#
# hamlet. ’twell.
#
#  [_exeunt._]
#
# scene i. the castav’s well.
#
# polonius. i would me not be look speak; but begingle; but the castam confess themexant more so his aught nothing are mus
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ied o’er with the pale cast of thought, "
# ied o’er with the pale cast of thought, by.
#
# horatio. drunknows lond i divided out the tiding, where dayser thoubask
# have swee you know.
#
# hamlet. then welco, day.
# roty, glo?but doint, my lor. but?
#
# first clown. emp;onabre heaven for ! modecolaid with will stail time trablow
# ala,y to thous. when ustempostle gaut his
# flather keep of havion the travement come your ober charge his grounder tone. mide at hands, but be! this plaype, to know w
# One combination completed
#
# ----------------------------------------
# Iteration 23
# 513/513 [==============================] - 15s 30ms/step - loss: 1.1529
#
# ----- diversity: 0.2
# ----- Generating with seed: "et, reading.
#
# queen. but look where sadl"
# et, reading.
#
# queen. but look where sadly the same contrication of all the of the hand help the project
# gutenberg-tm electronic work in the consequent in the strung the project
# gutenberg-tm works and did the property and did the matter shall speak of the strunger the state of the strunger to the project
# gutenberg-tm electronic work, and the states with sweep and for the matter that i shall speak to the play.
#
# king. therefore my soul’ th
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "et, reading.
#
# queen. but look where sadl"
# et, reading.
#
# queen. but look where sadlare you
# walt be thusmet. the coul of maddes and that you not your hands without to charisting to this for the unlactions to the very hath of grin in the very we
# away my be user prepitas and the dead it be the bebach, ear him are euse given in the can
# till my land?
#
# hamlet. therefore find of dead do not o, the eartion was a many to the songue, and project
# gutenberg-tm
# lacess thou leadsure man; to
# s
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "et, reading.
#
# queen. but look where sadl"
# et, reading.
#
# queen. but look where sadly the first roppersand, i
# dit out the , charistunt and whice in follow im right
# and rany congum, i comenel.
# thit!
#
#  enter parcent on and mist ’tairh
# with own head laigher is
# in thou win ausidibl were; and to
# libied?
#
# firsencues. i holden thou drast, you so you, and holations,
# my soulx. i’ll call ie pachest and hamlet.
# by the veny shall, his everinp-compritoy old,
# you, ’tis upon your disto night in
# One combination completed
#
# ----------------------------------------
# Iteration 24
# 513/513 [==============================] - 15s 30ms/step - loss: 1.1418
#
# ----- diversity: 0.2
# ----- Generating with seed: "ynaldo._]
#
#  enter ophelia.
#
# how now, oph"
# ynaldo._]
#
#  enter ophelia.
#
# how now, ophelia, and what is we see the project gutenberg-tm work is words and fore and with mine eyes of the election of a monething to the project gutenberg-tm work of a man like an distion of such to
#
# laest hamlet. the more the speak. if you say the speak! the play. and in the world in the hand help of the work our all bloom
# so shall we cannet. therefore in my best respied of the should be the bloody and
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ynaldo._]
#
#  enter ophelia.
#
# how now, oph"
# ynaldo._]
#
#  enter ophelia.
#
# how now, ophelia, but where most graver, in my bray and slead, let your incestion
# include, what forest the king’s mistribut and emose
# with so.
# comitaal in the iknou, from heaven states joyer,
# shall be sopponort of any ood
# no main. i thank itself, for what hath as a nature hath safffgecy so set you, that i am i reaution for of the enspate at as sirv.—
#
# hamlet. what.
#
# barnardo. i, forcelquline. what is, my lord
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ynaldo._]
#
#  enter ophelia.
#
# how now, oph"
# ynaldo._]
#
#  enter ophelia.
#
# how now, ophelia, come to va’d? i
# shall the ewh love.
#
# hamlet. i was your duad, laertes._] lether good in indurdist. forki_s. where fast, dumn. mar a bood which, for not
# broam. for anothers, that yetieus on repagaph suedfling which less, and of
# faith, no voryant. from there and might that
# surefape corning. what sa. bhoosly
# feationing his way, good
# cloug t dolwed teapps a moneths remaken to your project gyelna
# One combination completed
#
# ----------------------------------------
# Iteration 25
# 513/513 [==============================] - 15s 29ms/step - loss: 1.1366
#
# ----- diversity: 0.2
# ----- Generating with seed: "ing’s ears, and
# exits. the queen returns"
# ing’s ears, and
# exits. the queen returnster the players from him the project gutenberg active and the players the project gutenberg active and in the first to the project gutenberg accelle of the be the players that the world as in the project gutenberg accepte and the players the mount to the players come to the players to the perdone, and and wherein now, and in the cannon
# your and with the part the sunbation and profest to shall the
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "ing’s ears, and
# exits. the queen returns"
# ing’s ears, and
# exits. the queen returns.
#
# ; and you donation and blood; me, sith
# frie death, i fortuness. what is be, and i thus begin. these like with the lesterabarlive with the visagricance for make it watch, the thing, the players to might. i be windentenberg.
#
# sect withing here which is in the gland as him we meen of voice of didlques eaten or veauly of call and stoged. for use, in this groun the letter houldy. the cannoning our p
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "ing’s ears, and
# exits. the queen returns"
# ing’s ears, and
# exits. the queen returnsce, my lord.
#
# hamlet. it i
# for?wirs, prinon, and to some, my latingy:erclowingf,
# like; he is gone thus?
#
# rost as humuan your flatherve mort not
# look and promity worm. o anyl’d, a
# kings, as he both this rected
# please, in
# yor did mightemur replication liare, and
# groppote on your disto yon, my lord, ye ofwan, being opoveroose, it is ophelia, and that weed at this ass. therefores, near the neity, that
# One combination completed
#
# ----------------------------------------
# Iteration 26
# 513/513 [==============================] - 16s 30ms/step - loss: 1.1346
#
# ----- diversity: 0.2
# ----- Generating with seed: "aw pyrrhus make
# malicious sport in minci"
# aw pyrrhus make
# malicious sport in mincing be did please, that i did please of the work is the play, and which we have swots the project gutenberg-tm electronic works are not
# the more thus think of the counself
# shout to this wisesting to the project gutenberg-tm electronic works the true; and a most consevent to the play. i have seen that was a man. this work it work in the blood, that i will be think in the crease of disteraring to hea
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "aw pyrrhus make
# malicious sport in minci"
# aw pyrrhus make
# malicious sport in mincing let you not be this
# agreement, in the thing him my days.
#
# hamlet. what coused this work is becounl
# do?
#
# king. a rosencrantz and guildensters. what like is very have all obejection
# dost thou know, i will till hoth the thing him.
#
#  [_tor his distribution of lifel, sir’s that the
# precelonger shall known horsterfully
# hear thee be day than be; nory but driws of the fremed even stay the rest the wiss
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "aw pyrrhus make
# malicious sport in minci"
# aw pyrrhus make
# malicious sport in mincinhs to as
# throw me, tove for a bilt. to please. who long’d[e.
#
# than thbe?
#
# eapgual do beener the you, my ear, marry with all is breether and worm ray th’o, and
# thy conforn provis’ocitious fhar i that thin? with
# unlan’d
# plecked stith. ip a dived quil! ham eak
# will before that the shoughts of the works, i’t.
#
# guildens. and out. for the wi, what um
# to fail.
#  omen not?
#
# king,w?
#
# rosencrantz and guild
# One combination completed
#
# ----------------------------------------
# Iteration 27
# 513/513 [==============================] - 16s 30ms/step - loss: 1.1297
#
# ----- diversity: 0.2
# ----- Generating with seed: " to calculate your applicable taxes. the"
#  to calculate your applicable taxes. the project
# gutenberg air here and the first of the be disider.
#
# hamlet. ay, my lord, the project
# gutenberg-tm work is not be as a grace of the fine hear.
#
# hamlet. a room you do to the play. i have seen the cander to the black, who lends and the man and the most compolcownes the project
# gutenberg air here in the canners, her to the graperay.
#
# hamlet. and then as a groands and marcellence of the count
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: " to calculate your applicable taxes. the"
#  to calculate your applicable taxes. the dead for a be was not fail
# the phosse hall put on the players fear him fear them heaven marriess. he dread of the counsectidure
# that from whete hand he the king his life this wigneencents, whose confine. what dig we hath the general.
#
# hamlet. my lord, i side, did first words for
# lows ass? my it, my lord, and wrien, sir; if this beace, that was a
# gentleman? the castle dread into a regling of it.
#
#
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " to calculate your applicable taxes. the"
#  to calculate your applicable taxes. the
# arpesspelion leather! but gode, sir, and unlate; and my conseveutious and
# never daver on the freishine,—the wistrany power he?
# alf, soe, the munbate, kind: fell him not humst come.
#
# ophelia. did
# a sicked
# you much to siding proknat’d timeth. to youse horrhe forcess nnees your shurk them
# kinthen._]
#
# [_to do nothing.
#
# hamlet. he is thing shall?
#
# horatio. a?
#
# hamlet. or. far, harther and un. nownel,
# One combination completed
#
# ----------------------------------------
# Iteration 28
# 513/513 [==============================] - 16s 31ms/step - loss: 1.1263
#
# ----- diversity: 0.2
# ----- Generating with seed: "w to knock him about
# the sconce with a d"
# w to knock him about
# the sconce with a dost the beauty this play, the cander the matter state, and thing the cander what is the castle man as in the thing the project gutenberg-tm election, my lord, i have speak.
#
# hamlet. it is not lord shall be will be this work the command, the can thee me two my dear lair and the fould and with this partically be the project gutenberg-tm election, my lord.
#
# hamlet. i see in this a man, hamlet.
#
# hamle
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "w to knock him about
# the sconce with a d"
# w to knock him about
# the sconce with a dasteroush his fablinget on his eithent to lend and most trock as a brasion uncens to us a many of man, hamlet. by herews of press agreinor’s this’ acreason distribution, stange of his his advice, distribution of
# trich play’d this player men, and shall heaven, and impart to your hands dispassage, pyris
# king say to a mands life, and unwad, to she is further of an acture sound spirits.
#
#  [_exit._]
#
# k
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "w to knock him about
# the sconce with a d"
# w to knock him about
# the sconce with a douath; of valance of blood, raid.
#  indell start. now i, and
# he
# in byors arr.
#
# guiltenstern. farther’dity, but, this
# at they coups
# escapure, her
# nelt, guth your hamlet gapt in.
#
# hamlet. my morrord guildenstern.
#
# first planoms. it, belination and breather! then, as fast
# faity, and thing thut castle man, my wearish has
# stucks and wide of
# nonling, laertes, and that beant cannot me, and the teakestle p
# One combination completed
#
# ----------------------------------------
# Iteration 29
# 513/513 [==============================] - 15s 30ms/step - loss: 1.1225
#
# ----- diversity: 0.2
# ----- Generating with seed: "e’s bed. assume a
# virtue, if you have it"
# e’s bed. assume a
# virtue, if you have it is the state, and when thou and the prover in the canders.
#
# guildenstern. i have sens the day these have donations of the world the shows, the hand of the contane, and will have sweet of the contane, and where is a man and man, have play the castle king and contrates of the consele._]
#
# hamlet. then as you walk more to his beard of and with the prots and distribute and the thing to be will be the
# One combination completed
#
#
# ----- diversity: 0.7
# ----- Generating with seed: "e’s bed. assume a
# virtue, if you have it"
# e’s bed. assume a
# virtue, if you have it out assay.
#
# eacc my gond to we want me.
#
# rosencrantz. and what is marry, i shall how thus that in their electront plemen, shall blood.
#
# queen. have you, horatio and most surw will we have not refund the is to man, what is do to comes on this acrocuon of the heart, to be fad, and bot or heart and rown dishad not or not as this stain, pace of easedion of his acsouch, rany what we
# colk befa, why lat
# One combination completed
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "e’s bed. assume a
# virtue, if you have it"
# e’s bed. assume a
# virtue, if you have it connatured queen,on’d you all rosed, good clapos hus at cur[unce: k x le; to land me, which at the keepp unlive.
#
# ’tis
# the dead stlymand should.
#
# ophelia. whose cannati shall not see you despity
# con’s of urear.
#
# queen. what choriclious i notel od your dis’ awe of as thy
# man, larte too shulled bood sweet of his life
# to not me, sword cofuris
# comiat a head.
#
# king. nover metics youlbhow put anshak ot
# One combination completed
