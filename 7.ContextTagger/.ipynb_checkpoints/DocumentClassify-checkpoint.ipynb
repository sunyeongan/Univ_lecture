# %%
import nltk
import random
import feedparser

urls = {
    'mlb': 'https://sports.yahoo.com/mlb/rss.xml',
    'nfl': 'https://sports.yahoo.com/nfl/rss.xml',
}

feedmap = {}
stopwords = nltk.corpus.stopwords.words('english')

def featureExtractor(words):
    features = {}
    for word in words:
        if word not in stopwords:
            features["word({})".format(word)] = True
    return features

sentences = []

for category in urls.keys():
    feedmap[category] = feedparser.parse(urls[category])
    print("downloading {}".format(urls[category]))
    for entry in feedmap[category]['entries']:
        data = entry['summary']
        words = data.split()
        sentences.append((category, words))
# Out:
# downloading https://sports.yahoo.com/mlb/rss.xml
# downloading https://sports.yahoo.com/nfl/rss.xml

# %%
featuresets = [(featureExtractor(words), category) for category, words in sentences]
random.shuffle(featuresets)

print(featuresets)
# Out:
# [({'word(At)': True, 'word(2-4,)': True, 'word(time)': True, 'word(49ers)': True, 'word(make)': True, 'word(switch)': True, 'word(Jimmy)': True, 'word(Garoppolo)': True, 'word(Trey)': True, 'word(Lance?)': True, 'word(Joe)': True, 'word(Staley)': True, 'word(believes)': True, 'word(might)': True, 'word(ride)': True, 'word(rookie.)': True}, 'nfl'), ({'word(Postseason)': True, 'word(games)': True, 'word(averaged)': True, 'word(4.4)': True, 'word(million)': True, 'word(viewers)': True, 'word(TBS.)': True}, 'mlb'), ({'word(Brian)': True, 'word(Snitker,)': True, "word(Braves')": True, 'word(manager,)': True, 'word(take)': True, 'word(son,)': True, 'word(Troy,)': True, "word(Astros')": True, 'word(hitting)': True, 'word(coach,)': True, 'word(2021)': True, 'word(World)': True, 'word(Series.)': True}, 'mlb'), ({'word(The)': True, 'word(Detroit)': True, 'word(Lions,)': True, 'word(winless)': True, 'word(team)': True, 'word(NFL,)': True, 'word(check)': True, 'word(No.)': True, 'word(32)': True, 'word(second)': True, 'word(straight)': True, 'word(week,)': True, 'word(one)': True, 'word(spot)': True, 'word(ahead)': True, 'word(lowly)': True, 'word(Houston)': True, 'word(Texans.)': True}, 'nfl'), ({'word(MLB)': True, 'word(MLBPA)': True, 'word(negotiations)': True, 'word(recent)': True, 'word(months)': True, 'word(new)': True, 'word(CBA,)': True, 'word(current)': True, 'word(deal)': True, 'word(expires)': True, 'word(Dec.)': True, 'word(1.)': True}, 'mlb'), ({'word(Philadelphia)': True, 'word(Eagles)': True, 'word(Week)': True, 'word(7)': True, 'word(report)': True, 'word(card:)': True, 'word(Grading)': True, 'word(every)': True, 'word(position)': True, 'word(vs.)': True, 'word(Las)': True, 'word(Vegas)': True, 'word(Raiders)': True}, 'nfl'), ({'word(The)': True, 'word(Snitker)': True, 'word(family)': True, 'word(divided)': True, 'word(World)': True, 'word(Series,)': True, 'word(father)': True, 'word(son)': True, 'word(opposing)': True, 'word(dugouts.)': True}, 'mlb'), ({'word(Seattle)': True, 'word(Seahawks)': True, 'word(head)': True, 'word(coach)': True, 'word(Pete)': True, 'word(Carroll)': True, 'word(speaks)': True, 'word(candidly)': True, 'word(injured)': True, 'word(quarterback)': True, 'word(Russell)': True, 'word(Wilson,)': True, 'word(saying)': True, "word('If)": True, 'word(Russell,)': True, 'word(I)': True, 'word(probably)': True, 'word(long)': True, "word(time.')": True, 'word(This)': True, 'word(game)': True, 'word(streaming)': True, 'word(live)': True, 'word(Yahoo)': True, 'word(Sports)': True, 'word(mobile)': True, 'word(app,)': True, 'word(NFL)': True, 'word(Network)': True}, 'nfl'), ({'word(Saints)': True, 'word(left)': True, 'word(guard)': True, 'word(Andrus)': True, 'word(Peat)': True, 'word(Monday)': True, 'word(night’s)': True, 'word(win)': True, 'word(injury)': True, 'word(initial)': True, 'word(belief)': True, 'word(going)': True, 'word(keep)': True, 'word(action)': True, 'word(extended)': True, 'word(period)': True, 'word(time.)': True, 'word(The)': True, 'word(team)': True, 'word(said)': True, 'word(shoulder)': True, 'word(game,)': True, 'word(Ian)': True, 'word(Rapoport)': True, 'word(NFL)': True, 'word(Media)': True, 'word(reports)': True, 'word([more])': True}, 'nfl'), ({'word(Here)': True, 'word(latest)': True, 'word(New)': True, 'word(York)': True, "word(Mets')": True, 'word(front)': True, 'word(office)': True, 'word(search...)': True}, 'mlb'), ({'word(Report:)': True, 'word(Saints)': True, 'word(fear)': True, 'word(season-ending)': True, 'word(pectoral)': True, 'word(muscle)': True, 'word(injury)': True, 'word(Andrus)': True, 'word(Peat)': True}, 'nfl'), ({'word(On)': True, 'word(BNNY,)': True, 'word(Doug)': True, 'word(Williams)': True, 'word(asks)': True, 'word(Jim)': True, 'word(Duquette)': True, 'word(type)': True, 'word(long-term)': True, 'word(contract)': True, 'word(would)': True, 'word(give)': True, 'word(Michael)': True, 'word(Conforto,)': True, 'word(light)': True, 'word(possible)': True, 'word(qua ...

# %%
total = len(featuresets)
off = int(total/2)
trainset = featuresets[off:]
testset = featuresets[:off]

classifier = nltk.NaiveBayesClassifier.train(trainset)

print(nltk.classify.accuracy(classifier, testset))

classifier.show_most_informative_features(5)
for (i, entry) in enumerate(feedmap['nfl']['entries']):
    if i < 4:
        features = featureExtractor(entry['title'].split())
        category = classifier.classify(features)
        print('{} -> {}'.format(category, entry['summary']))
# Out:
# 0.803921568627451
# Most Informative Features
#            word(Houston) = True              mlb : nfl    =      3.6 : 1.0
#               word(Kyle) = True              nfl : mlb    =      2.0 : 1.0
#          word(including) = True              nfl : mlb    =      2.0 : 1.0
#               word(last) = True              nfl : mlb    =      2.0 : 1.0
#               word(line) = True              nfl : mlb    =      2.0 : 1.0
# nfl -> The 49ers entered the season with much fanfare, but San Francisco is 2-4 and Kyle Shanahan has some serious issues that need attention.
# mlb -> Matt Nagy's offensive line could use help in pass protection, so any help from the rookie tackles would be welcome.
# nfl -> Seattle Seahawks head coach Pete Carroll speaks candidly about injured Seahawks quarterback Russell Wilson, saying that 'If we didn't have Russell, I probably wouldn't have been here a long time.' This game is streaming live on the Yahoo Sports mobile app, or on NFL Network
# nfl -> The New Orleans Saints fear left guard Andrus Peat suffered a torn pectoral against the Seattle Seahawks on 'Monday Night Football' in Week 7 of the 2021 NFL regular season. This game is streaming live on the Yahoo Sports mobile app, or on NFL Network
